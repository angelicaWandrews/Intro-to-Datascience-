# %% [markdown]
# # CAP 5768 - Data Science - Dr. Marques - Fall 2019

# %% [markdown]
# ## Assignment 2: Exploratory data analysis

# %% [markdown]
# ### Goals
#
# - To increase familiarity with the Python "data science stack" (NumPy, Pandas, Matplotlib).
# - To explore (manipulate, summarize, and visualize) datasets.
# - To improve the ability to write Python code to answer questions and test hypotheses based on the contents of those datasets.

# %% [markdown]
# ### Instructions
#
# - This assignment is structured in three parts, using a different dataset for each part.
# - For each part, there will be some Python code to be written and questions to be answered.
# - At the end, you should export your notebook to PDF format; it will "automagically" become your report.
# - Submit the report (PDF), notebook (.ipynb file), and (optionally) link to the "live" version of your solution on Google Colaboratory via Canvas.
# - The total number of points is 154 (plus up to 85 bonus points), distributed as follows: Part 1 (58+ pts), Part 2 (28+ pts), Part 3 (43+ pts), and Conclusions (25 pts).

# %% [markdown]
# ### Important
#
# - It is OK to attempt the bonus points, but please **do not overdo it!**
# - Remember: this is an exercise in performing exploratory data analysis; expanding (and practicing) your knowledge of Python, Jupyter notebooks, Numpy, Pandas, and Matplotlib; and writing code to test hypotheses and  answer questions based on the available data (and associated summary statistics).
# - This is not (yet) the time to do sophisticated statistical analysis, train ML models, etc.
# - You must **organize your data files in the proper folders** for the code to work.

# %% [markdown]
# -------------------
# ## Part 1: The MovieLens 1M dataset
#
# This is a dataset of movie ratings data collected from users of MovieLens in the late 1990s and early 2000s. The data provide movie ratings, movie metadata, and demographic data about the users. Such data is often of interest in the development of recommendation systems based on machine learning algorithms.
#
# The MovieLens 1M dataset contains ~1 million ratings collected from ~6,000 users on ~4,000 movies. It's spread across three tables: _ratings_, _user information_, and _movie information_. After extracting the data from the ZIP file (available on Canvas), we can load each table into a pandas DataFrame object using the Python code below.
#
# See:
# https://grouplens.org/datasets/movielens/ for additional information.

# %%
# Imports
import numpy as np
import pandas as pd
from pandas import DataFrame, Series

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import pearsonr

# %% [markdown]
# Before running the cell below, make sure that you have downloaded the movielens.zip file from Canvas, unzipped it, and placed its contents under the 'data' folder.
#
# ![movielens_path.png](attachment:movielens_path.png)

# %%
import pandas as pd

# Make display smaller
pd.options.display.max_rows = 10

unames = ['user_id', 'gender', 'age', 'occupation', 'zip']
users = pd.read_csv('https://raw.githubusercontent.com/angelicaWandrews/Intro-to-Datascience-/master/movielens/movielens/users.dat', sep='::',
                      header=None, names=unames, engine='python')

rnames = ['user_id', 'movie_id', 'rating', 'timestamp']
ratings = pd.read_csv('https://raw.githubusercontent.com/angelicaWandrews/Intro-to-Datascience-/master/movielens/movielens/ratings.dat', sep='::',
                        header=None, names=rnames, engine='python')

mnames = ['movie_id', 'title', 'genres']
movies = pd.read_csv('https://raw.githubusercontent.com/angelicaWandrews/Intro-to-Datascience-/master/movielens/movielens/movies.dat', sep='::',
                       header=None, names=mnames, engine='python')

# %% [markdown]
# # Your turn! (24 points, i.e., 6 pts each)
#
# Write Python code to answer the following questions (make sure the messages displayed by your code are complete and descriptive enough):
# 1. How many users are stored in the _users_ table and what information is stored for each user?
# 2. How many movies are stored in the _movies_ table and what information is stored for each movie?
# 3. How many ratings are stored in the _ratings_ table and what information is stored for each rating?
# 4. How are users, the movies each user has rated, and the rating related?
#
# *Note*: ages and occupations are coded as integers indicating _groups_ described in the dataset’s README file.

# %%
# !cat 'https://raw.githubusercontent.com/angelicaWandrews/Intro-to-Datascience-/master/movielens/movielens/README'
# Out:
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## Solution

# %% [markdown]
# (ENTER YOUR ANSWERS HERE)

# %%
# ENTER YOUR CODE HERE
# ...
# ...
# ...
# Q: How many users are stored in the users table and what information is stored for each user?
# A: 6040 users in total,for each user there is the user_id, gender, age, occupation, and zip
users.info()
# Q: How many movies are stored in the movies table and what information 
# is stored for each movie?
# A: 3883 movies, per movie there is a movie_id, title, and genere
movies.info()
# Q: How many ratings are stored in the ratings table and what information 
# is stored for each rating?
# A: 1000209 ratings, per entry there is a user_id, movie_id, rating, and timestamp
ratings.info()
# Q: How are users, the movies each user has rated, and the rating related?
# The ratings contain the user_id and movie_id that is shared from the movis and users tables
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6040 entries, 0 to 6039
# Data columns (total 5 columns):
# user_id       6040 non-null int64
# gender        6040 non-null object
# age           6040 non-null int64
# occupation    6040 non-null int64
# zip           6040 non-null object
# dtypes: int64(3), object(2)
# memory usage: 236.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3883 entries, 0 to 3882
# Data columns (total 3 columns):
# movie_id    3883 non-null int64
# title       3883 non-null object
# genres      3883 non-null object
# dtypes: int64(1), object(2)
# memory usage: 91.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000209 entries, 0 to 1000208
# Data columns (total 4 columns):
# user_id      1000209 non-null int64
# movie_id     1000209 non-null int64
# rating       1000209 non-null int64
# timestamp    1000209 non-null int64
# dtypes: int64(4)
# memory usage: 30.5 MB

# %% [markdown]
# # Your turn! (24 points, i.e., 6 pts each)
#
# Write Python code to answer the following questions (make sure the messages displayed by your code are complete and descriptive enough):
# 5. What is the occupation that maps to most of the users? Optionally, plot a bar chart of the occupation counts and report the size of the largest bin.
# 6. What percentage of users are 50 years old or older? Plot a pie chart showing all percentages (per age group) and report the requested value.
# 7. Which movie received the highest number of ratings (and how were such ratings distributed)?
# 8. What is the average rating for all movies/users?

# %% [markdown]
# ## Solution

# %% [markdown]
# (ENTER YOUR ANSWERS HERE)

# %%
# ENTER YOUR CODE HERE
# ...
# ...
# ...
def print_full(x):
    pd.set_option('display.max_rows', len(x))
    print(x)
    pd.reset_option('display.max_rows')
    
# Q: What is the occupation that maps to most of the users? 
# A: 4:  "college/grad student"
# Even though the at the 50% quartile, the value is 7, the one that most users have is 4
users.describe()
sorted_occupation_of_users=users['occupation'].sort_values()
print_full(sorted_occupation_of_users.value_counts())

# Q: Plot a histogram of the occupation counts and report the size of the largest bin.
# sorted_occupation_of_users.hist()
# plt.show()
plt.bar(sorted_occupation_of_users.value_counts().index, sorted_occupation_of_users.value_counts().values)
plt.show()
y, x, _ = plt.hist(sorted_occupation_of_users, bins=21)
print(x.max())
print(y.max())
plt.show()
# Out:
# 4     759
# 0     711
# 7     679
# 1     528
# 17    502
# 12    388
# 14    302
# 20    281
# 2     267
# 16    241
# 6     236
# 10    195
# 3     173
# 15    144
# 13    142
# 11    129
# 5     112
# 9      92
# 19     72
# 18     70
# 8      17
# Name: occupation, dtype: int64
# 20.0
# 759.0

# %%
# Q:  What percentage of users are 50 years old or older? 
# 0.14503311258278145 => 14.503%
percent_over_50=(users[users['age']>=50]['age'].count())/users['age'].count()
# Plot a pie chart showing all percentages (per age group) and report the requested value.
age_series=users.age.value_counts()
colors=['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','moccasin','violet','cyan']
plt.pie(age_series.values,labels=age_series.index.values,colors=colors,autopct='%1.1f%%')
plt.axis('equal')
plt.legend()
plt.show()

# %%
# Q: Which movie received the highest number of ratings (and how were such ratings distributed)?
#  A: Movie with movie_id 2858
#  A: From movies table, this is the info for the movie with that id
#  A: 2789      2858  American Beauty (1999)  Comedy|Drama
movie_with_highest_rating=ratings[ratings['movie_id']==ratings['movie_id'].value_counts().idxmax()]
print(movies[movies['movie_id']==ratings['movie_id'].value_counts().idxmax()])
rating_count=movie_with_highest_rating['rating'].value_counts()
# shows the plot that has the distribution curve for 
# the rating value count for the movie with most ratings
# A:the distribution for this movie has a higher concentration on 5 stars. Ratings seem 
# to grow exponentially
plt.bar(rating_count.index,rating_count.values)

# shows how many users rated a certain type of rating
print(rating_count)
# shows the datasets distribution
print(movie_with_highest_rating.describe())
# Out:
#       movie_id                   title        genres
# 2789      2858  American Beauty (1999)  Comedy|Drama
# 5    1963
# 4     890
# 3     358
# 2     134
# 1      83
# Name: rating, dtype: int64
#            user_id  movie_id       rating     timestamp
# count  3428.000000    3428.0  3428.000000  3.428000e+03
# mean   2918.450117    2858.0     4.317386  9.708757e+08
# std    1729.578363       0.0     0.975133  8.879782e+06
# min       2.000000    2858.0     1.000000  9.567045e+08
# 25%    1422.500000    2858.0     4.000000  9.652501e+08
# 50%    2887.500000    2858.0     5.000000  9.732139e+08
# 75%    4414.250000    2858.0     5.000000  9.748645e+08
# max    6040.000000    2858.0     5.000000  1.046368e+09

# %%
# Q: What is the average rating for all movies/users?
# 3.581564453029317
print(ratings['rating'].mean())
# Out:
# 3.581564453029317

# %% [markdown]
# -------------------
# We will use the Python code below to merge all three tables into a unified data frame.

# %%
data = pd.merge(pd.merge(ratings, users), movies)
data
# Out:
#          user_id  movie_id  rating   timestamp gender  age  occupation    zip  \
# 0              1      1193       5   978300760      F    1          10  48067
# 1              2      1193       5   978298413      M   56          16  70072
# 2             12      1193       4   978220179      M   25          12  32793
# 3             15      1193       4   978199279      M   25           7  22903
# 4             17      1193       5   978158471      M   50           1  95350
# 5             18      1193       4   978156168      F   18           3  95825
# 6             19      1193       5   982730936      M    1          10  48073
# 7             24      1193       5   978136709      F   25           7  10023
# 8             28      1193       3   978125194      F   25           1  14607
# 9             33      1193       5   978557765      M   45           3  55421
# 10            39      1193       5   978043535      M   18           4  61820
# ...

# %% [markdown]
# The Python code below will show the top 10 films among female viewers (and, for comparison's sake, the ratings for those movies by male viewers) in decreasing order (highest rated movie on top).

# %%
# Build pivot table
mean_ratings = data.pivot_table('rating', index='title',
                                columns='gender', aggfunc='mean')

# Group ratings by title
ratings_by_title = data.groupby('title').size()

# Select only movies with 250 ratings or more
active_titles = ratings_by_title.index[ratings_by_title >= 250]

# Select rows on the index
mean_ratings = mean_ratings.loc[active_titles]

# Fix naming inconsistency
mean_ratings = mean_ratings.rename(index={'Seven Samurai (The Magnificent Seven) (Shichinin no samurai) (1954)':
                           'Seven Samurai (Shichinin no samurai) (1954)'})

top_female_ratings = mean_ratings.sort_values(by='F', ascending=False)
top_female_ratings[:10]
# Out:
# gender                                                     F         M
# title
# Close Shave, A (1995)                               4.644444  4.473795
# Wrong Trousers, The (1993)                          4.588235  4.478261
# Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)       4.572650  4.464589
# Wallace & Gromit: The Best of Aardman Animation...  4.563107  4.385075
# Schindler's List (1993)                             4.562602  4.491415
# Shawshank Redemption, The (1994)                    4.539075  4.560625
# Grand Day Out, A (1992)                             4.537879  4.293255
# To Kill a Mockingbird (1962)                        4.536667  4.372611
# Creature Comforts (1990)                            4.513889  4.272277
# Usual Suspects, The (1995)                          4.513317  4.518248

# %% [markdown]
# # Your turn! (10 points, i.e., 5 pts each)
#
# Modify the Python code to:
# 9. Display the top 10 favorite movies among male viewers, selecting only movies with 250 ratings or more.
# 10. Display the top 10 favorite movies among young viewers (17 years old or younger), selecting only movies with 300 ratings or more.

# %% [markdown]
# ## Solution

# %%
# ENTER YOUR CODE HERE
# ...
# ...
# ...
# Q: Display the top 10 favorite movies among male viewers, 
# selecting only movies with 250 ratings or more.
top_male_ratings = mean_ratings.sort_values(by='M', ascending=False)
top_male_ratings[:10]
# Out:
# gender                                              F         M
# title
# Godfather, The (1972)                        4.314700  4.583333
# Seven Samurai (Shichinin no samurai) (1954)  4.481132  4.576628
# Shawshank Redemption, The (1994)             4.539075  4.560625
# Raiders of the Lost Ark (1981)               4.332168  4.520597
# Usual Suspects, The (1995)                   4.513317  4.518248
# Star Wars: Episode IV - A New Hope (1977)    4.302937  4.495307
# Schindler's List (1993)                      4.562602  4.491415
# Wrong Trousers, The (1993)                   4.588235  4.478261
# Close Shave, A (1995)                        4.644444  4.473795
# Rear Window (1954)                           4.484536  4.472991

# %%
# Q: Display the top 10 favorite movies among young viewers (17 years old or younger), 
# selecting only movies with 300 ratings or more.
count = data.pivot_table('rating', index='title',
                                columns='age', aggfunc='mean')
# Group ratings by title
ratings_by_title_age = data.groupby('title').size()

# Select only movies with 250 ratings or more
active_titles_age = ratings_by_title_age.index[ratings_by_title_age >= 300]

# Select rows on the index
count = count.loc[active_titles_age]

top_young_ratings = count.sort_values(by=1, ascending=False)
top_young_ratings[:10]
# Out:
# age                                1         18        25        35        45  \
# title
# Metropolis (1926)            4.888889  3.872340  4.079470  4.032967  4.119048
# GoodFellas (1990)            4.840000  4.457912  4.355714  4.154321  3.929134
# Third Man, The (1949)        4.818182  4.346939  4.402516  4.475248  4.431818
# Double Indemnity (1944)      4.777778  4.372881  4.471338  4.363057  4.460317
# Piano, The (1993)            4.750000  3.408451  3.696000  3.681818  3.666667
# Fried Green Tomatoes (1991)  4.750000  3.734513  3.687783  3.844828  3.879310
# Raging Bull (1980)           4.714286  4.439560  4.190114  4.148387  3.903226
# Roman Holiday (1953)         4.687500  4.290909  4.248175  4.136842  4.000000
# Citizen Kane (1941)          4.680000  4.392405  4.365854  4.400000  4.339130
# Notorious (1946)             4.666667  4.268293  4.238095  4.295652  4.258621
#
# age                                50        56
# title
# ...

# %% [markdown]
# # BONUS! (up to 20 points)
#
# Write Python code to display the most divisive movies (selecting only movies with 250 ratings or more), i.e.:
# - The top 10 movies with the greatest rating difference so that we can see which ones were preferred by women.
# - The top 10 movies with the greatest rating difference in the opposite direction (sign) so that we can see which ones were preferred by men.
#
# Hint/Convention: ``mean_ratings['diff'] = mean_ratings['M'] - mean_ratings['F']``

# %% [markdown]
# ## Solution

# %%
# ENTER YOUR CODE HERE
# ...
# ...
# ...
# Q: The top 10 movies with the greatest rating difference so that we can see 
# which ones were preferred by women.
mean_ratings['diff'] = mean_ratings['M'] - mean_ratings['F']
top_diff_ratings = mean_ratings.sort_values(by='diff', ascending=True)
top_diff_ratings[:10]
# Out:
# gender                                        F         M      diff
# title
# Dirty Dancing (1987)                   3.790378  2.959596 -0.830782
# Jumpin' Jack Flash (1986)              3.254717  2.578358 -0.676359
# Grease (1978)                          3.975265  3.367041 -0.608224
# Little Women (1994)                    3.870588  3.321739 -0.548849
# Steel Magnolias (1989)                 3.901734  3.365957 -0.535777
# Anastasia (1997)                       3.800000  3.281609 -0.518391
# Rocky Horror Picture Show, The (1975)  3.673016  3.160131 -0.512885
# Color Purple, The (1985)               4.158192  3.659341 -0.498851
# Age of Innocence, The (1993)           3.827068  3.339506 -0.487561
# Free Willy (1993)                      2.921348  2.438776 -0.482573

# %%
# Q: The top 10 movies with the greatest rating difference in the opposite 
# direction (sign) so that we can see which ones were preferred by men.
low_diff_ratings = mean_ratings.sort_values(by='diff', ascending=False)
low_diff_ratings[:10]
# Out:
# gender                                         F         M      diff
# title
# Good, The Bad and The Ugly, The (1966)  3.494949  4.221300  0.726351
# Kentucky Fried Movie, The (1977)        2.878788  3.555147  0.676359
# Dumb & Dumber (1994)                    2.697987  3.336595  0.638608
# Longest Day, The (1962)                 3.411765  4.031447  0.619682
# Cable Guy, The (1996)                   2.250000  2.863787  0.613787
# Evil Dead II (Dead By Dawn) (1987)      3.297297  3.909283  0.611985
# Hidden, The (1987)                      3.137931  3.745098  0.607167
# Rocky III (1982)                        2.361702  2.943503  0.581801
# Caddyshack (1980)                       3.396135  3.969737  0.573602
# For a Few Dollars More (1965)           3.409091  3.953795  0.544704

# %% [markdown]
# # BONUS! (up to 10 points)
#
# Write Python code to display the top 10 movies (with 250 ratings or more) that elicited the most disagreement among viewers, independent of gender identification.
#
# Hint: Disagreement can be measured by the _variance_ or _standard deviation_ of the ratings.

# %% [markdown]
# ## Solution

# %%
# ENTER YOUR CODE HERE
# ...
# ...
# ...
# Q: Write Python code to display the top 10 movies (with 250 ratings or more) that elicited 
# the most disagreement among viewers, independent of gender identification.
ratings_top = data.pivot_table('rating',index='title', aggfunc='mean')
# Group ratings by title
ratings_by_title_total = data.groupby('title').size()

# Select only movies with 250 ratings or more
active_titles_total = ratings_by_title_age.index[ratings_by_title_total >= 250]

# Select rows on the index
ratings_top = ratings_top.loc[active_titles_total]

ratings_top['diff'] = ratings_top['rating']-ratings_top['rating'].std()

ratings_top[:10]
# Out:
#                                        rating      diff
# title
# 'burbs, The (1989)                   2.910891  2.405710
# 10 Things I Hate About You (1999)    3.422857  2.917676
# 101 Dalmatians (1961)                3.596460  3.091279
# 101 Dalmatians (1996)                3.046703  2.541522
# 12 Angry Men (1957)                  4.295455  3.790273
# 13th Warrior, The (1999)             3.158667  2.653486
# 2 Days in the Valley (1996)          3.283217  2.778036
# 20,000 Leagues Under the Sea (1954)  3.702609  3.197428
# 2001: A Space Odyssey (1968)         4.068765  3.563583
# 2010 (1984)                          3.417021  2.911840

# %% [markdown]
# # BONUS! (up to 10 points)
#
# Write Python code to answer the question:
# What is the most popular movie genre?
# Plot a histogram of the genre counts and report the size of the largest bin.
#
# Hint: use the original **movies** data frame, _before_ the merge!

# %% [markdown]
# ## Solution

# %%
# ENTER YOUR CODE HERE
# ...
# ...
# ...
# Q: Write Python code to answer the question: What is the most popular movie genre? 
# A: Drama                                            843
genre_count=movies['genres'].value_counts()
print("Genre of max liked: ", genre_count.idxmax(), " Number: ", genre_count.max())
# Q: Plot a histogram of the genre counts and report the size of the largest bin.
# A: 843.0
# plt.bar(genre_count.index,genre_count.values)
# plt.show()
y, x, _ = plt.hist(genre_count.values)
print(x.max())
print(y.max())
plt.show()
# Out:
# Genre of max liked:  Drama  Number:  843
# 843.0
# 293.0

# %%
# Just to double check that I am right
data.pivot_table('title',index='genres',columns='rating',aggfunc='count').sort_values(by=5, ascending = False)
# Out:
# rating                                              1        2        3  \
# genres
# Drama                                          3497.0   8538.0  26693.0
# Comedy                                         8106.0  14513.0  31971.0
# Comedy|Drama                                   1652.0   3722.0  10403.0
# Comedy|Romance                                 1944.0   4880.0  12535.0
# Drama|Romance                                  1255.0   3080.0   7761.0
# Drama|War                                       255.0    635.0   2454.0
# Drama|Thriller                                  575.0   1540.0   4270.0
# Action|Drama|War                                284.0    624.0   2114.0
# Action|Thriller                                1175.0   2909.0   7788.0
# Action|Sci-Fi|Thriller                          808.0   1505.0   3173.0
# Crime|Drama                                     225.0    685.0   2468.0
# Thriller                                        902.0   2024.0   4750.0
# ...

# %% [markdown]
# ------------
# ## Part 2: Titanic

# %% [markdown]
# In this part we'll use the dataset of passengers on the *Titanic*, available through the Seaborn library.
#
# See https://www.kaggle.com/c/titanic/data for codebook and additional information.

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ## Questions 11-14 (16 points total, i.e. 4 pts each)
#
# Look at the Python code below and answer the following questions (expressing the amounts in % terms):
#
# 11. How many female passengers did not survive (regardless of their class)?
#
# A: 0.257962
# 12. How many first class female passengers did not survive?
#
# A:0.031915
# 13. How many male passengers did not survive (regardless of their class)?
#
# A: 0.811092
# 14. How many third class male passengers did not survive?
#
# A: 0.864553

# %%
titanic.pivot_table('survived', index='sex', columns='class', margins=True)
# Out:
# class      First    Second     Third       All
# sex
# female  0.968085  0.921053  0.500000  0.742038
# male    0.368852  0.157407  0.135447  0.188908
# All     0.629630  0.472826  0.242363  0.383838

# %%
sns.catplot(x="sex", y="survived", hue="class", kind="bar", data=titanic);

# %% [markdown]
# ## Solution

# %% [markdown]
# (ENTER YOUR ANSWER HERE)
#
# 11. A: 0.257962
#
# 12. A: 0.031915
#
# 13. A: 0.811092
#
# 14. A: 0.864553

# %%
1-titanic.pivot_table('survived', index='sex', columns='class', margins=True)
# Out:
# class      First    Second     Third       All
# sex
# female  0.031915  0.078947  0.500000  0.257962
# male    0.631148  0.842593  0.864553  0.811092
# All     0.370370  0.527174  0.757637  0.616162

# %% [markdown]
# ## Your turn! (12 points, i.e., 4 pts each)
#
# Write Python code to answer the following questions (make sure the messages displayed by your code are complete and descriptive enough):
#
# 15. How many passengers (absolute number) were there per deck/class?
#
# (**Hint**: The plot below shows how decks and classes were related and provides a visual estimate.)
# 16. How many passengers (absolute number) in Deck A survived?
# 17. How many passengers (absolute number) in Deck E survived and what was the breakdown (in Deck E) per class?
#
# ![example_categorical_plot_titanic.png](attachment:example_categorical_plot_titanic.png)

# %% [markdown]
# ## Solution

# %%
# ENTER YOUR CODE HERE
# ...
# ...
# ...

pv_table=titanic.pivot_table("survived",index='deck', columns='class', aggfunc='count',margins=True)
# 15. How many passengers (absolute number) were there per deck/class? 
# (**Hint**: The plot below shows how decks and classes were related and provides a visual estimate.)
# 16. How many passengers (absolute number) in Deck A survived?
# 17. How many passengers (absolute number) in Deck E survived and what was the breakdown (in Deck E) per class?
print('Total Passenger: ', pv_table['All']['All'])
print('Total A', pv_table['All']['A'])
print('Deck A First: ', pv_table['First']['A'])
print('Deck A Second: ', pv_table['Second']['A'])
print('Deck A Third: ', pv_table['Third']['A'] )
# Out:
# Total Passenger:  203
# Total A 15
# Deck A First:  15.0
# Deck A Second:  nan
# Deck A Third:  nan

# %%
print('Total B', pv_table['All']['B'])
print('Deck B First: ', pv_table['First']['B'])
print('Deck B Second: ', pv_table['Second']['B'])
print('Deck B Third: ', pv_table['Third']['B'] )
# Out:
# Total B 47
# Deck B First:  47.0
# Deck B Second:  nan
# Deck B Third:  nan

# %%
print('Total C', pv_table['All']['C'])
print('Deck C First: ', pv_table['First']['C'])
print('Deck C Second: ', pv_table['Second']['C'])
print('Deck C Third: ', pv_table['Third']['C'] )
# Out:
# Total C 59
# Deck C First:  59.0
# Deck C Second:  nan
# Deck C Third:  nan

# %%
print('Total D', pv_table['All']['D'])
print('Deck D First: ', pv_table['First']['D'])
print('Deck D Second: ', pv_table['Second']['D'])
print('Deck D Third: ', pv_table['Third']['D'] )
# Out:
# Total D 33
# Deck D First:  29.0
# Deck D Second:  4.0
# Deck D Third:  nan

# %%
print('Total E', pv_table['All']['E'])
print('Deck E First: ', pv_table['First']['E'])
print('Deck E Second: ', pv_table['Second']['E'])
print('Deck E Third: ', pv_table['Third']['E'] )
# Out:
# Total E 32
# Deck E First:  25.0
# Deck E Second:  4.0
# Deck E Third:  3.0

# %%
print('Total F', pv_table['All']['F'])
print('Deck F First: ', pv_table['First']['F'])
print('Deck F Second: ', pv_table['Second']['F'])
print('Deck F Third: ', pv_table['Third']['F'] )
# Out:
# Total F 13
# Deck F First:  nan
# Deck F Second:  8.0
# Deck F Third:  5.0

# %%
print('Total G', pv_table['All']['G'])
print('Deck G First: ', pv_table['First']['G'])
print('Deck G Second: ', pv_table['Second']['G'])
print('Deck G Third: ', pv_table['Third']['G'] )

pv_table
# Out:
# Total G 4
# Deck G First:  nan
# Deck G Second:  nan
# Deck G Third:  4.0
# class  First  Second  Third  All
# deck
# A       15.0     NaN    NaN   15
# B       47.0     NaN    NaN   47
# C       59.0     NaN    NaN   59
# D       29.0     4.0    NaN   33
# E       25.0     4.0    3.0   32
# F        NaN     8.0    5.0   13
# G        NaN     NaN    4.0    4
# All    175.0    16.0   12.0  203

# %% [markdown]
# # BONUS! (up to 20 points)
#
# Write Python code to answer the following questions (using percentage values):
# - How many women traveling alone did not survive?
# - How many men 35 years old or younger did not survive?
# - What was the average fare per class?

# %% [markdown]
# ## Solution

# %%
# ENTER YOUR CODE HERE
# ...
# ...
# ...
# How many women traveling alone did not survive?
# titanic.info()
alone_w_n_sruvive = len(titanic[(titanic['alone']==True) & (titanic['survived']==0) & (titanic['sex']=='female')])
percent_w_n_survive = alone_w_n_sruvive/len(titanic)
print("Percent of women traveling along who did not survive: ",percent_w_n_survive*100,"%")

# How many men 35 years old or younger did not survive?
men_35_n = len(titanic[(titanic['age']<=35) & (titanic['survived']==0) & (titanic['sex']=='male')])
percent_men_35_n = men_35_n/len(titanic)
print("Percent of men of 35 years or younger who did not survive: ",percent_men_35_n*100,"%")

# What was the average fare per class?
class_grouping=titanic.groupby(['class']).mean()
fare_grouped_by_class=class_grouping['fare']
print("Average Fare for First Class: ",fare_grouped_by_class['First'])
print("Average Fare for Second Class: ",fare_grouped_by_class['Second'])
print("Average Fare for Third Class: ",fare_grouped_by_class['Third'])
# Out:
# Percent of women traveling along who did not survive:  3.0303030303030303 %
# Percent of men of 35 years or younger who did not survive:  27.160493827160494 %
# Average Fare for First Class:  84.15468749999992
# Average Fare for Second Class:  20.66218315217391
# Average Fare for Third Class:  13.675550101832997

# %% [markdown]
# ------------
# ## Part 3: US Baby Names 1880–2018

# %% [markdown]
# The United States Social Security Administration (SSA) has made available data on the frequency of baby names from 1880 through the present. These plain text data files, one per year, contain the total number of births for each sex/name combination. The raw archive of these files can be obtained from http://www.ssa.gov/oact/babynames/limits.html.
#
# After downloading the 'National data' file _names.zip_ and unzipping it, you will have a directory containing a series of files like _yob1880.txt_ through _yob2018.txt_. We need to do some data wrangling to load this dataset (see code below).

# %% [markdown]
# For your convenience, I have made the _names.zip_ file available on Canvas.
# Before running the cell below, make sure that you have downloaded it, unzipped it, and placed its contents under the 'data' folder.
#
# ![names_path.png](attachment:names_path.png)

# %%
years = range(1880, 2019)

pieces = []
columns = ['name', 'sex', 'births']

for year in years:
    path = 'data/names/yob%d.txt' % year
    frame = pd.read_csv(path, names=columns)

    frame['year'] = year
    pieces.append(frame)

# Concatenate everything into a single DataFrame
names = pd.concat(pieces, ignore_index=True)

# %%
names
# Out:
#               name sex  births  year
# 0             Mary   F    7065  1880
# 1             Anna   F    2604  1880
# 2             Emma   F    2003  1880
# 3        Elizabeth   F    1939  1880
# 4           Minnie   F    1746  1880
# 5         Margaret   F    1578  1880
# 6              Ida   F    1472  1880
# 7            Alice   F    1414  1880
# 8           Bertha   F    1320  1880
# 9            Sarah   F    1288  1880
# 10           Annie   F    1258  1880
# 11           Clara   F    1226  1880
# 12            Ella   F    1156  1880
# 13        Florence   F    1063  1880
# 14            Cora   F    1045  1880
# 15          Martha   F    1040  1880
# 16           Laura   F    1012  1880
# 17          Nellie   F     995  1880
# 18           Grace   F     982  1880
# 19          Carrie   F     949  1880
# 20           Maude   F     859  1880
# 21           Mabel   F     808  1880
# 22          Bessie   F     796  1880
# 23          Jennie   F     793  1880
# ...

# %% [markdown]
# ## Your turn! (25 points)
#
# Write Python code to compute the number of baby boys and baby girls born each year and display the two line plots over time.
#
# Hint: Start by aggregating the data at the year and sex level using ``groupby`` or ``pivot_table``.
#
# Your plot should look like this:
#
# ![birth_vs_year.png](attachment:birth_vs_year.png)

# %% [markdown]
# ## Solution

# %%
# ENTER YOUR CODE HERE
# ...
# ...
# ...
# Write Python code to compute the number of baby boys and baby girls born each year 
# and display the two line plots over time. 
# Hint: Start by aggregating the data at the year and sex level using groupby or pivot_table.
birth_sex_table=names.pivot_table('births', columns='year', index= 'sex', aggfunc='sum')
birth_sex_table.loc['F']
plt.plot(birth_sex_table.columns, birth_sex_table.loc['F'], color='seagreen',label='Female')
plt.plot(birth_sex_table.columns, birth_sex_table.loc['M'], color='olive', label='Male')
plt.legend()

# %%
birth_sex_table
# Out:
# year    1880    1881    1882    1883    1884    1885    1886    1887    1888  \
# sex
# F      90994   91953  107847  112319  129019  133055  144533  145981  178622
# M     110490  100743  113686  104625  114442  107799  110785  101412  120851
#
# year    1889  ...     2009     2010     2011     2012     2013     2014  \
# sex           ...
# F     178366  ...  1835062  1775345  1756592  1758171  1751320  1782350
# M     110580  ...  1981481  1916476  1896574  1893975  1888009  1916564
#
# year     2015     2016     2017     2018
# sex
# F     1780453  1766212  1719138  1686961
# M     1911537  1891585  1842837  1800392
#
# [2 rows x 139 columns]

# %% [markdown]
# -------------
# ## Analyzing Naming Trends
#
# Suppose we're interested in analyzing the Top 1000 most popular baby names per year.
#
# We will do so by following these steps:
# 1. Insert a column _prop_ with the fraction of babies given each name relative to the total number of births. A prop value of 0.02 would indicate that 2 out of every 100 babies were given a particular name in a given year.
# 2. Group the data by year and sex, then add the new column to each group.
# 3. Extract a subset of the data (the top 1,000 names for each sex/year combination). This is yet another group operation.
# 4. Split the Top 1,000 names into the boy and girl portions.
# 5. Build a pivot table of the total number of births by year and name.
#
# Finally, we will plot the percentage of babies named 'John', 'Noah', 'Madison', or 'Lorraine' over time.

# %%
# 1. Insert a column _prop_ with the fraction of babies given each name relative to the total number of 
# births. A prop value of 0.02 would indicate that 2 out of every 100 babies were given a particular name 
# in a given year. 
def add_prop(group):
    group['prop'] = group.births / group.births.sum()
    return group
# 2. Group the data by year and sex, then add the new column to each group.
names = names.groupby(['year', 'sex']).apply(add_prop)

# %%
# names

# %%
# Sanity check (all percentages should add up to 1, i.e., 100%)
# names.groupby(['year', 'sex']).prop.sum()

# %%
def get_top1000(group):
    return group.sort_values(by='births', ascending=False)[:1000]

# 3. Extract a subset of the data (the top 1,000 names for each sex/year combination). 
# This is yet another group operation.
grouped = names.groupby(['year', 'sex'])
top1000 = grouped.apply(get_top1000)
# Drop the group index, not needed
top1000.reset_index(inplace=True, drop=True)

# %%
# top1000

# %%
# 4. Split the Top 1,000 names into the boy and girl portions.
boys = top1000[top1000.sex == 'M']
girls = top1000[top1000.sex == 'F']

# %%
# 5. Build a pivot table of the total number of births by year and name.
total_births = top1000.pivot_table('births', index='year',
                                   columns='name',
                                   aggfunc=sum)

# %%
total_births.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 139 entries, 1880 to 2018
# Columns: 7174 entries, Aaden to Zyaire
# dtypes: float64(7174)
# memory usage: 7.6 MB

# %%
# Finally, we will plot the percentage of babies named 'John', 'Noah', 'Madison', or 'Lorraine' over time.
subset = total_births[['John', 'Noah', 'Madison', 'Lorraine']]
subset.plot(subplots=True, figsize=(12, 10), grid=False,
            title="Number of births per year")
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000280299D73C8>,
# ...
#       dtype=object)

# %% [markdown]
# --------------
# # BONUS! (up to 25 points)
#
# Write Python code to test the hypothesis:
#
# H1: There has been an increase in naming diversity over time.
#
# Hint: Compute a metric that consists of the number of distinct names, taken in order of popularity from highest to lowest, in the top 50% of births, and plot that metric over time.
#
# Your plot should look like this:
#
# ![naming_diversity.png](attachment:naming_diversity.png)

# %% [markdown]
# ## Solution

# %%
# Hint: Compute a metric that consists of the number of distinct names, taken in order of popularity 
# from highest to lowest, in the top 50% of births, and plot that metric over time.

a=names.groupby(['year','name','sex']).aggregate(np.sum)
val=int(round(len(a)/2))
b=a.sort_values(by=['births'],ascending=False).iloc[:val]
# b=b.groupby(['year','name','sex']).aggregate('count')
b['year']=b.index.get_level_values('year') 
b['name']=b.index.get_level_values('name')
b['sex']=b.index.get_level_values('sex')

b=b.reset_index(drop=True)
b = b.sort_values(by=['year'],ascending=False)
b=b.reset_index(drop=True)

temp=[]
temp1=[]
for i in b['year'].unique().tolist():
    temp.append([len(b[(b['year']==i)&(b['sex']=='F')]['name'].unique().tolist()),i])
    temp1.append([len(b[(b['year']==i)&(b['sex']=='M')]['name'].unique().tolist()),i])
    
f=pd.DataFrame(temp,columns=['unique_names','year'])
m=pd.DataFrame(temp1,columns=['unique_names','year'])

# %%
plt.plot(f.year, f.unique_names, color='seagreen',label='Female')
plt.plot(m.year, m.unique_names, color='olive', label='Male')
plt.legend()
plt.show()

# %% [markdown]
# -------------
# ## Boy names that became girl names (and vice versa)
#
# Next, let's look at baby names that were more popular with one sex earlier in the sample but have switched to the opposite sex over the years. One example is the name Lesley or Leslie (or other possible, less common, spelling variations).
#
# We will do so by following these steps:
# 1. Go back to the top1000 DataFrame and compute a list of names occurring in the dataset starting with “lesl”.
# 2. Filter down to just those names and sum births grouped by name to see the relative frequencies.
# 3. Aggregate by sex and year and normalize within year.
# 4. Plot the breakdown by sex over time.

# %%
# 1. Go back to the top1000 DataFrame and compute a list of names occurring 
# in the dataset starting with “lesl”.
all_names = pd.Series(top1000.name.unique())
lesley_like = all_names[all_names.str.lower().str.contains('lesl')]
lesley_like
# Out:
# 632     Leslie
# 2294    Lesley
# 4264    Leslee
# 4732     Lesli
# 6108     Lesly
# dtype: object

# %%
# 2. Filter down to just those names and sum births grouped by name to see the relative frequencies.
filtered = top1000[top1000.name.isin(lesley_like)]
filtered.groupby('name').births.sum()
# Out:
# name
# Leslee       993
# Lesley     35033
# Lesli        929
# Leslie    378168
# Lesly      11433
# Name: births, dtype: int64

# %%
# 3. Aggregate by sex and year and normalize within year.
table = filtered.pivot_table('births', index='year',
                             columns='sex', aggfunc='sum')
table = table.div(table.sum(1), axis=0)

# %%
# 4. Plot the breakdown by sex over time.
fig = plt.figure()
table.plot(style={'M': 'b-', 'F': 'r--'})

# %% [markdown]
# ---------------------
#
# Now it's time for you to come up with a different hypotheses, which we will call H2. **Be creative!**
#
# Example: The name 'Reese' has been more prevalent among baby girls than baby boys since 2000.

# %% [markdown]
# ## Your turn! (28 points)
#
# Write Python code to test hypothesis H2 (and some text to explain whether it was confirmed or not
#
# Hypthesis H2: Past the year 1886, more babies were named after cars. 1886 was the year the first gasoline car was made by the Benz Patent-Motorwagen patent, made by Carl Benz and was the first production car. Car brands that would be baby names Lincoln, Bently, ROyce, Chevy, Mercedes, Ford, Lexus, Ram, Dodge, Kia, Audi, Tesla, Mercury, Nissan, Infiniti, Jaguar, McLaren.

# %% [markdown]
# ## Solution
#
# The lowest year in which car names were around, but not frequently in use was in 1880 (the beginning of the dataset). Those names were the following:
#
# 121       8  0.000072  1880      Ford
#
# 384      10  0.000091  1880   Lincoln
#
# 522       6  0.000066  1880  Mercedes
#
#
# Visibly, they are not popular in the beginning, but later on they become more popular. Especially Mercedes where you can see a spike of popularity. The name Lincoln becomes extermely popular past the 2000s, but that can also be attributed to the former president of the US. Interesting to note however, names like Ford become more popular in the past 2010 by over 50% of previous popularity. Names like Mercedes and Nissan, see a spike in popularity atfter the car brand is launched (Nissan in 1993 almost doubles and Kia in 1988 Mercedes grows in popularity when the car brand is more luxorious. This is not always the case observed all the time, however, it is interesting to note that some names that are not around in 1880 appear later and grow in popularity, just so happenly when the associated car brand rises in popularity, it is unfair to say that there is a direct correlation, but there is most probably some relation as you see an upward trend of car names used for babies as time progresses, but not by an overwhelming amount.

# %%
# ENTER YOUR CODE HERE
# ...
# ...
# ...
car_names=['Lincoln', 'Bently', 'Royce', 'Chevy', 'Mercedes', 'Ford', 'Lexus', 'Ram', 'Dodge', 'Kia', 
           'Audi', 'Tesla', 'Mercury', 'Nissan', 'Infiniti', 'Jaguar', 'McLaren','Porsche']
baby_cars = names[names['name'].isin(car_names)]
# baby_cars=baby_cars.groupby(['year','name','sex']).sum()
baby_cars=baby_cars.groupby(['year','name']).sum()
baby_cars['year']=baby_cars.index.get_level_values('year') 
baby_cars['name']=baby_cars.index.get_level_values('name')
# baby_cars['sex']=baby_cars.index.get_level_values('sex')


baby_cars=baby_cars.reset_index(drop=True)
baby_cars=baby_cars.sort_values(by=['name','year'])
baby_cars=baby_cars.reset_index(drop=True)
car_names=sorted(car_names)

temp=[]
for i in range(len(car_names)):
    temp.append([baby_cars[baby_cars['name']==car_names[i]]])

Audi=pd.DataFrame(temp[0].pop(0))
Bently=pd.DataFrame(temp[1].pop(0))
Chevy=pd.DataFrame(temp[2].pop(0))
Dodge=pd.DataFrame(temp[3].pop(0))
Ford=pd.DataFrame(temp[4].pop(0))
Infiniti=pd.DataFrame(temp[5].pop(0))
Jaguar=pd.DataFrame(temp[6].pop(0))
Kia=pd.DataFrame(temp[7].pop(0))
Lexus=pd.DataFrame(temp[8].pop(0))
Lincoln=pd.DataFrame(temp[9].pop(0))
# McLaren=pd.DataFrame(temp[10])
Mercedes=pd.DataFrame(temp[11].pop(0))
Mercury=pd.DataFrame(temp[12].pop(0))
Nissan=pd.DataFrame(temp[13].pop(0))
Porsche=pd.DataFrame(temp[14].pop(0))
Ram=pd.DataFrame(temp[15].pop(0))
Royce=pd.DataFrame(temp[16].pop(0))
Tesla=pd.DataFrame(temp[17].pop(0))

plt.plot(Audi.year, Audi.births, color='seagreen',label='Audi')
plt.plot(Bently.year, Bently.births, color='orange', label='Bently')
plt.plot(Chevy.year, Chevy.births, color='gold',label='Chey')
plt.plot(Dodge.year, Dodge.births, color='purple', label='Dodge')
plt.plot(Ford.year, Ford.births, color='cyan',label='Ford')
plt.plot(Infiniti.year, Infiniti.births, color='pink', label='Infiniti')
plt.plot(Jaguar.year, Jaguar.births, color='green',label='Jaguar')
plt.plot(Kia.year, Kia.births, color='blue', label='Kia')
plt.plot(Lexus.year, Lexus.births, color='tan',label='Lexus')
plt.plot(Lincoln.year, Lincoln.births, color='lightblue', label='Lincoln')
plt.plot(Mercedes.year, Mercedes.births, color='black',label='Mercedes')
plt.plot(Mercury.year, Mercury.births, color='grey', label='Mercury')
plt.plot(Nissan.year, Nissan.births, color='olive',label='Nissan')
plt.plot(Porsche.year, Porsche.births, color='red',label='Porsche')
plt.plot(Ram.year, Ram.births, color='darkblue',label='Ram')
plt.plot(Royce.year, Royce.births, color='orchid', label='Royce')
plt.plot(Tesla.year, Tesla.births, color='linen',label='Tesla')
plt.legend(loc='best')

plt.show()

print(baby_cars[baby_cars['year']==baby_cars['year'].min()])
# Out:
#      births      prop  year      name
# 121       8  0.000072  1880      Ford
# 384      10  0.000091  1880   Lincoln
# 522       6  0.000066  1880  Mercedes

# %% [markdown]
# ## Conclusions (25 points)
#
# Write your conclusions and make sure to address the issues below:
# - What have you learned from this assignment?
# - Which parts were the most fun, time-consuming, enlightening, tedious?
# - What would you do if you had an additional week to work on this?

# %% [markdown]
# ## Solution

# %% [markdown]
# (WRITE YOUR CONCLUSIONS HERE)
# - What have you learned from this assignment?
#
# In this assignment, I learned how to how to use the pivot table to partition columns and create meaning ful calculations on combinations of columns. I generally used the broupby statement, but the pivot tabl was pretty cool. I also learned how to get the levels on a multi-index dataframe and draw some meaningful statistcs from there (using the aggfunc).
#
# - Which parts were the most fun, time-consuming, enlightening, tedious?
#
# The most time consuming was the last bonus question, which required some more thinking about how to tackle the problem. The most fun was seeing how people reallydo name their babies after car brands and luxury items. The most enlightening was using the pivot table, which was another way to partion the dataframe and do some menaingful calculations. The most tedious were all the graphs for formatting reasons.
#
# - What would you do if you had an additional week to work on this?
#
# If I had an additional week, I would make a model that would cluster groups of like baby names.
